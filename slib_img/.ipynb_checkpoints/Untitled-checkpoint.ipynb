# %%
import cv2
import slib_img as si
import matplotlib.pyplot as plt
import os

# %%
img_path = '/Users/songminglun/research/slib/test/S014_001_00000021.png'

# %%
I = si.Img(img_path)

# %%
I.flip()

# %%
I.save()

# %%
def preproce(path):
    I = si.Img(path)
    os.remove(path)
    I.gray()
    I.choose_face()
    I.save(path)
    I.flip()
    I.save(path[:-4] + '_' + 'flip' +'.png')

# %%
preproce(img_path)
